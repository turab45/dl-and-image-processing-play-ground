# %% [markdown]
# <a href="https://colab.research.google.com/github/turab45/dl-and-image-processing-play-ground/blob/master/play_with_audio_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# imports
import librosa
import matplotlib.pyplot as plt
import librosa.display
import IPython.display as ipd
import numpy as np
# %matplotlib inline

# %%
x, sr = librosa.load('simpleLoop.wav')

# %%
print(x.shape)
print(sr)
# Out:
# (66150,)
# 22050

# %%
# visualize an audio
plt.figure(figsize=(14, 5))
librosa.display.waveplot(x, sr=sr)

# %%
# Display spectrogram
X = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')

# %%
# play audio
ipd.Audio('/content/simpleLoop.wav')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Let's synthesize a pure tone at 440 Hz
import numpy
sr = 22050 # sample rate
T = 2.0    # seconds
t = numpy.linspace(0, T, int(T*sr), endpoint=False) # time variable
x = 0.5*numpy.sin(2*numpy.pi*440*t)                # pure sine wave at 440 Hz

# %%
ipd.Audio(x, rate=sr) # load a NumPy array
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# write an audio data
print(librosa.__version__)
# Out:
# 0.8.1

# %%
S = np.abs(librosa.stft(x))
chroma = librosa.feature.chroma_stft(S=S, sr=sr)

# visualize
fig, ax = plt.subplots()
img = librosa.display.specshow(chroma, y_axis='chroma', x_axis='time', ax=ax)
fig.colorbar(img, ax=ax)
ax.set(title='Chromagram')
# Out:
# [Text(0.5, 1.0, 'Chromagram')]
